# %%
import pandas as pd

# Binarized Matrix
df = pd.read_csv('binlinking.tsv.gz', compression='gzip', sep = '\t', index_col = 0)#, header=0, sep=' ', quotechar='"', error_bad_lines=False)

# Weight Matrix
# df = pd.read_csv('linking.tsv.gz', compression='gzip', sep = '\t', index_col = 0)#, header=0, sep=' ', quotechar='"', error_bad_lines=False)

df
# Out:
#         A1BG   AAAS   AACS  AAGAB   AAK1  AAMDC   AAMP   AAR2  AARS2  AARSD1  \
# ARNT   False  False  False  False  False  False  False  False  False   False
# ASCL2  False  False  False  False  False  False  False  False   True   False
# ATF1   False  False   True  False   True  False  False   True  False   False
# ATF2   False  False   True  False  False  False  False   True  False   False
# ATF3   False  False  False  False  False  False  False  False  False   False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# ZEB1    True  False  False  False  False  False  False  False   True   False
# ZFHX3  False  False  False  False  False  False  False  False  False   False
# ZFX    False   True  False   True  False   True   True  False  False   False
# ZIC2   False   True  False   True   True  False  False  False   True   False
# ZNF76  False  False  False  False  False  False  False  False  False   False
#
# ...

# %%
X = df.to_numpy()
print(X.min())
print(X.max())
# Out:
# False
# True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline

n_plot_target_genes = 300

for i in [0,1]: #range(int(math.floor(len(df.columns))/200)):
    plt.figure(figsize = (40,30))
    sns.heatmap(df.to_numpy()[:,:n_plot_target_genes],yticklabels = list(df.index), xticklabels = list(df.columns)[:n_plot_target_genes])#, vmin = -10, vmax = 10)
    plt.show()

# %%
X = df.to_numpy()
print(X.sum(axis = 0).mean())
print(X.sum(axis = 0).min())
print(X.sum(axis = 0).max())
# Out:
# 19.99524465023151
# 2
# 20
